# %%
## Question 
# (a)
import boto3
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans
from skfuzzy.cluster import cmeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Defining s3 bucket
s3 = boto3.resource('s3')
bucket_name = 'gabrielferreira-data-455-bucket'
bucket = s3.Bucket(bucket_name)

# Defining the file to be read from s3 bucket
key_file = 'customers.csv'

bucket_object = bucket.Object(key_file)
file_object = bucket_object.get()
file_content_stream = file_object.get('Body')

# Reading csv
customers = pd.read_csv(file_content_stream)

customers.head()
# Out:
#    ID  Visit_Time  Average_Expense  Sex  Age
# 0   1           3              5.7    0   10
# 1   2           5             14.5    0   27
# 2   3          16             33.5    0   32
# 3   4           5             15.9    0   30
# 4   5          16             24.9    0   23

# %%
pip install -U scikit-fuzzy
# Out:
# Requirement already satisfied: scikit-fuzzy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.4.2)
# Requirement already satisfied: scipy>=0.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-fuzzy) (1.5.3)
# Requirement already satisfied: numpy>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-fuzzy) (1.19.5)
# Requirement already satisfied: networkx>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-fuzzy) (2.5)
# Requirement already satisfied: decorator>=4.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from networkx>=1.9.0->scikit-fuzzy) (4.4.2)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
## Dropping ID
customers = customers.drop(columns = 'ID', axis = 1)
customers.head()
# Out:
#    Visit_Time  Average_Expense  Sex  Age
# 0           3              5.7    0   10
# 1           5             14.5    0   27
# 2          16             33.5    0   32
# 3           5             15.9    0   30
# 4          16             24.9    0   23

# %%
## Transforming variables to 0-1 scale
scaler = MinMaxScaler()

customers[['Visit_Time_0_1', 'Average_Expense_0_1', 'Age_0_1']] = scaler.fit_transform(customers[['Visit_Time', 'Average_Expense', 'Age']])
customers.head()
# Out:
#    Visit_Time  Average_Expense  Sex  Age  Visit_Time_0_1  Average_Expense_0_1  \
# 0           3              5.7    0   10        0.117647             0.041096
# 1           5             14.5    0   27        0.235294             0.342466
# 2          16             33.5    0   32        0.882353             0.993151
# 3           5             15.9    0   30        0.235294             0.390411
# 4          16             24.9    0   23        0.882353             0.698630
#
#     Age_0_1
# 0  0.051282
# 1  0.487179
# 2  0.615385
# 3  0.564103
# 4  0.384615

# %%
results = list()

for i in range(2,21):
    
    ## Clustering the data
    kmeans_md = KMeans(n_clusters = i, n_init = 20).fit(customers[['Sex', 'Visit_Time_0_1', 'Average_Expense_0_1', 'Age_0_1']])
    kmeans_labels = kmeans_md.labels_
    
    results.append(silhouette_score(customers[['Sex', 'Visit_Time_0_1', 'Average_Expense_0_1', 'Age_0_1']], kmeans_labels))
    
plt.plot(range(2,21), results)
plt.xlabel('Number of cluster')
plt.ylabel('silhouette score')
plt.grid()
plt.show()

# %%
X = customers[['Sex', 'Visit_Time_0_1', 'Average_Expense_0_1', 'Age_0_1']]

fc, W, u0, d, jm, p, pc = cmeans(X.T, c = 4, m = 1.25, error = 1e-6, maxiter = 1000)

# %%
customers['cluster'] = np.nan
customers.head()
# Out:
#    Visit_Time  Average_Expense  Sex  Age  Visit_Time_0_1  Average_Expense_0_1  \
# 0           3              5.7    0   10        0.117647             0.041096
# 1           5             14.5    0   27        0.235294             0.342466
# 2          16             33.5    0   32        0.882353             0.993151
# 3           5             15.9    0   30        0.235294             0.390411
# 4          16             24.9    0   23        0.882353             0.698630
#
#     Age_0_1  cluster
# 0  0.051282      NaN
# 1  0.487179      NaN
# 2  0.615385      NaN
# 3  0.564103      NaN
# 4  0.384615      NaN

# %%
customers['cluster'] = np.where(W[0] > 0.7, 1, customers['cluster'])
customers['cluster'] = np.where(W[1] > 0.7, 2, customers['cluster'])
customers['cluster'] = np.where(W[2] > 0.7, 3, customers['cluster'])
customers['cluster'] = np.where(W[3] > 0.7, 4, customers['cluster'])
customers.head()
# Out:
#    Visit_Time  Average_Expense  Sex  Age  Visit_Time_0_1  Average_Expense_0_1  \
# 0           3              5.7    0   10        0.117647             0.041096
# 1           5             14.5    0   27        0.235294             0.342466
# 2          16             33.5    0   32        0.882353             0.993151
# 3           5             15.9    0   30        0.235294             0.390411
# 4          16             24.9    0   23        0.882353             0.698630
#
#     Age_0_1  cluster
# 0  0.051282      3.0
# 1  0.487179      3.0
# 2  0.615385      2.0
# 3  0.564103      3.0
# 4  0.384615      2.0

# %%
cluster_1 = customers[customers['cluster'] == 1].reset_index(drop = True)
cluster_1.describe()
# Out:
#        Visit_Time  Average_Expense   Sex        Age  Visit_Time_0_1  \
# count   24.000000        24.000000  24.0  24.000000       24.000000
# mean     5.416667        10.591667   1.0  15.291667        0.259804
# std      2.430185         4.474752   0.0   4.666990        0.142952
# min      1.000000         4.500000   1.0   8.000000        0.000000
# 25%      3.000000         7.875000   1.0  11.750000        0.117647
# 50%      6.000000        10.900000   1.0  16.000000        0.294118
# 75%      7.000000        12.000000   1.0  17.500000        0.352941
# max     10.000000        23.800000   1.0  23.000000        0.529412
#
#        Average_Expense_0_1    Age_0_1  cluster
# count            24.000000  24.000000     24.0
# mean              0.208619   0.186966      1.0
# std               0.153245   0.119666      0.0
# min               0.000000   0.000000      1.0
# 25%               0.115582   0.096154      1.0
# 50%               0.219178   0.205128      1.0
# 75%               0.256849   0.243590      1.0
# max               0.660959   0.384615      1.0

# %% [markdown]
# #### In cluster 1, we have 24 males around of 18 years old who spent, on average, 21 dollars.

# %%
cluster_2 = customers[customers['cluster'] == 2].reset_index(drop = True)
cluster_2.describe()
# Out:
#        Visit_Time  Average_Expense  Sex        Age  Visit_Time_0_1  \
# count    8.000000         8.000000  8.0   8.000000        8.000000
# mean    14.375000        25.587500  0.0  26.625000        0.786765
# std      1.846812         4.647714  0.0   5.629958        0.108636
# min     12.000000        18.800000  0.0  18.000000        0.647059
# 25%     13.500000        22.950000  0.0  22.750000        0.735294
# 50%     14.000000        25.400000  0.0  26.000000        0.764706
# 75%     16.000000        28.500000  0.0  32.250000        0.882353
# max     17.000000        33.500000  0.0  33.000000        0.941176
#
#        Average_Expense_0_1   Age_0_1  cluster
# count             8.000000  8.000000      8.0
# mean              0.722175  0.477564      2.0
# std               0.159168  0.144358      0.0
# min               0.489726  0.256410      2.0
# 25%               0.631849  0.378205      2.0
# 50%               0.715753  0.461538      2.0
# 75%               0.821918  0.621795      2.0
# max               0.993151  0.641026      2.0

# %% [markdown]
# #### In cluster 2, we have 8 females around of 47 years old who spent, on average, 72 dollars.

# %%
cluster_3 = customers[customers['cluster'] == 3].reset_index(drop = True)
cluster_3.describe()
# Out:
#        Visit_Time  Average_Expense   Sex       Age  Visit_Time_0_1  \
# count   11.000000        11.000000  11.0  11.00000       11.000000
# mean     4.909091        12.709091   0.0  17.00000        0.229947
# std      1.700267         6.060108   0.0   6.78233        0.100016
# min      3.000000         4.600000   0.0   9.00000        0.117647
# 25%      3.500000         7.150000   0.0  12.00000        0.147059
# 50%      5.000000        14.500000   0.0  16.00000        0.235294
# 75%      6.000000        16.000000   0.0  20.00000        0.294118
# max      8.000000        23.800000   0.0  30.00000        0.411765
#
#        Average_Expense_0_1    Age_0_1  cluster
# count            11.000000  11.000000     11.0
# mean              0.281133   0.230769      3.0
# std               0.207538   0.173906      0.0
# min               0.003425   0.025641      3.0
# 25%               0.090753   0.102564      3.0
# 50%               0.342466   0.205128      3.0
# 75%               0.393836   0.307692      3.0
# max               0.660959   0.564103      3.0

# %% [markdown]
# #### In cluster 3, we have 11 females around of 23 years old who spent, on average, 28 dollars.

# %%
cluster_4 = customers[customers['cluster'] == 4].reset_index(drop = True)
cluster_4.describe()
# Out:
#        Visit_Time  Average_Expense   Sex        Age  Visit_Time_0_1  \
# count   16.000000        16.000000  16.0  16.000000       16.000000
# mean    12.250000        25.362500   1.0  31.187500        0.661765
# std      2.955221         4.336339   0.0   8.336416        0.173837
# min      8.000000        17.800000   1.0  17.000000        0.411765
# 25%     10.000000        21.100000   1.0  26.000000        0.529412
# 50%     12.000000        25.450000   1.0  28.500000        0.647059
# 75%     13.250000        28.275000   1.0  36.750000        0.720588
# max     18.000000        33.700000   1.0  47.000000        1.000000
#
#        Average_Expense_0_1    Age_0_1  cluster
# count            16.000000  16.000000     16.0
# mean              0.714469   0.594551      4.0
# std               0.148505   0.213754      0.0
# min               0.455479   0.230769      4.0
# 25%               0.568493   0.461538      4.0
# 50%               0.717466   0.525641      4.0
# 75%               0.814212   0.737179      4.0
# max               1.000000   1.000000      4.0

# %% [markdown]
# #### In cluster 4, we have 16 males around of 59 years old who spent, on average, 71 dollars.
